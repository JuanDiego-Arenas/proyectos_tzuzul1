# %% [markdown]
# ## Inicio con pandas

# %%
import pandas as pd
import random

df = pd.read_csv('dataset.csv', index_col = 'id')
df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ### Limpieza de "Datos"

# %%
df_filtrado = df.fillna('Indefinido')
df_filtrado.head()
# Out:
#                                                 full_text favorites  \
# id
# 183721  Flying home to run down from the power to comi...      23.0
# 183722                Today we commemorate and MNML Case.     500.0
# 183723       Today we have reached US$6.55 Billion TT$44…     190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...     131.0
# 183725                                    Welcome back! 🙌     113.0
#
#           retweets    mentions  country           user followers  followees
# id
# 183721  Indefinido        10.0  ECUADOR  leonardokuffo     389.0        258
# 183722        21.0  Indefinido   BRASIL  mateusmartins     982.0       1822
# 183723       123.0         6.0   MEXICO    pedrojuarez      12.0        129
# 183724        76.0         3.0  ECUADOR   galocastillo     332.0        378
# 183725       130.0         9.0   MEXICO    pedrojuarez      12.0        129

# %% [markdown]
# ### Filtrado de Datos
# - Por columnas
# - Por filas (usando incices o etiquetas)

# %% [markdown]
# ##### Por columnas

# %%
df_columnas = df[['full_text', 'favorites']]
df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ##### Por filas (Indices o etiquetas)

# %%
df_filtrado.iloc[0] # Indices
# Out:
# full_text    Flying home to run down from the power to comi...
# favorites                                                 23.0
# retweets                                            Indefinido
# mentions                                                  10.0
# country                                                ECUADOR
# user                                             leonardokuffo
# followers                                                389.0
# followees                                                  258
# Name: 183721, dtype: object

# %%
df.iloc[0:2] # Rango de indices
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822

# %%
df_filtrado.iloc[[1, 0, 5]] # Indices individuales
# Out:
#                                                 full_text favorites  \
# id
# 183722                Today we commemorate and MNML Case.     500.0
# 183721  Flying home to run down from the power to comi...      23.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!     492.0
#
#           retweets    mentions  country           user followers  followees
# id
# 183722        21.0  Indefinido   BRASIL  mateusmartins     982.0       1822
# 183721  Indefinido        10.0  ECUADOR  leonardokuffo     389.0        258
# 183726        70.0         6.0   BRASIL  mateusmartins     982.0       1822

# %% [markdown]
# ## Función "loc"

# %%
df.loc[[183721, 183722]] # Filtrado por 'id' en filas
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822

# %%
df_filtrado.loc[[183721, 183722], ['favorites', 'retweets']]  # Filtrado por 'filas' (usando el id) y 'columnas' (usando etiquetas)
# Out:
#        favorites    retweets
# id
# 183721      23.0  Indefinido
# 183722     500.0        21.0

# %% [markdown]
# ### Filtrado por condiciones

# %%
df[(df['favorites'] > 400) & (df['mentions'] > 20)] # Condición numérica
# Out:
#                                         full_text  favorites  retweets  \
# id
# 183744                                Thanks man!      430.0     143.0
# 183745  There is nothing better than programming!      424.0     110.0
# 183746                                   BORED AF      488.0      28.0
#
#         mentions country             user  followers  followees
# id
# 183744      28.0  BRASIL       lucasperes        NaN        351
# 183745      29.0  BRASIL       lucasperes       82.0        351
# 183746      27.0  MEXICO  gabrielcarvajal       21.0       2721

# %%
df[df['full_text'].str.contains('Programming')]
# Out:
#                           full_text  favorites  retweets  mentions  country  \
# id
# 183733     Programming is the best!      467.0      69.0      10.0  ECUADOR
# 183740  Programming is a hot topic!      133.0     145.0      15.0   BRASIL
# 183741      Programming? i love it!       92.0     146.0       1.0  ECUADOR
#
#                  user  followers  followees
# id
# 183733  leonardokuffo      389.0        258
# 183740     lucasperes       82.0        351
# 183741   galocastillo      332.0        378

# %%
def calcular_ganancias(retweets):
    ganancias = retweets * random.randint(3, 5)
    return ganancias
    
df['ganancias'] = df['retweets'].apply(calcular_ganancias)

def popularidad(fila):
    resultado = fila['followees']/fila['followers']
    return resultado

df['popularidad'] = df.apply(popularidad, axis = 1)
df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees  \
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129
#
#         ganancias  popularidad
# id
# 183721        NaN     0.663239
# 183722      105.0     1.855397
# ...

# %% [markdown]
# ## Agrupación por datos categoricos

# %%
df.groupby('country').mean() # Agrupación de una sola operación
# Out:
#           favorites   retweets  mentions  followers    followees   ganancias  \
# country
# BRASIL   339.909091  91.272727    19.600    616.600  1889.363636  371.636364
# ECUADOR  186.375000  64.857143    11.875    360.500   318.000000  270.142857
# MEXICO   294.857143  77.750000    13.750     15.375  1101.000000  281.875000
#
#          popularidad
# country
# BRASIL      3.708644
# ECUADOR     0.900897
# MEXICO     55.308036

# %%
grupo = df.groupby('country').agg({ # con la función ".agg" puedo aplicar diferente funciones de agregación
    'followers':'sum',
    'mentions':'mean',
    'retweets':'max'
})

grupo[grupo['followers'] > 5000]
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0      19.6     145.0

# %%
import matplotlib.pyplot as plt

grupo['followers'].plot(kind = 'barh')
plt.show()
