# %%
# df es la variable del data_set

import pandas as pd
df = pd.read_csv('kdrama.csv')
# df.head(1)

# %%
# dfk es la variable modificada "arreglada" del data_set, para su correcta visualización
# y manejo de uso

dfk = df[['Name', 'Year of release', 'N° Episode','Platform', 'Genre', 'Rank', 'Rating']]
dfk.set_index('Rank').head(5)
# Out:
#                      Name  Year of release  N° Episode        Platform  \
# Rank
# #1         Move to Heaven             2021          10        Netflix
# #2      Hospital Playlist             2020          12  Netflix,  tvN
# #3         Flower of Evil             2020          16            tvN
# #4    Hospital Playlist 2             2021          12  Netflix,  tvN
# #5              My Mister             2018          16            tvN
#
#                                         Genre  Rating
# Rank
# #1                     Life,  Drama,  Family      9.2
# #2     Friendship,  Romance,  Life,  Medical      9.1
# #3    Thriller,  Romance,  Crime,  Melodrama      9.1
# #4     Friendship,  Romance,  Life,  Medical      9.1
# #5     Psychological,  Life,  Drama,  Family      9.1

# %%
# "Ejemplo/Practica" de filtrado por 'Rating' (valor >= 8.8) y 'Genre'

# dfk[dfk['Genre'].str.contains('Comedy', 'Romance')]
dfk[(dfk['Rating'] >= 8.8) & dfk['Genre'].str.contains('Comedy', 'Romance')]
# Out:
#                                Name  Year of release  N° Episode  \
# 5                   Prison Playbook             2017          16
# 6                        Reply 1988             2015          20
# 7          It's Okay to Not Be Okay             2020          16
# 8                         Mr. Queen             2020          20
# 13                         Vincenzo             2021          20
# 14             Crash Landing on You             2019          16
# 20                           Goblin             2016          16
# 21             Hometown Cha-Cha-Cha             2021          16
# 23                             D.P.             2021           6
# 26  Weightlifting Fairy Kim Bok Joo             2016          16
# 28                     Life on Mars             2018          16
# 34                      Racket Boys             2021          16
#
#           Platform                                      Genre Rank  Rating
# ...
